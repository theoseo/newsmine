# %%
import glob

files = glob.glob('./newsdata/2014/*/newsisall.json')

# %%
import json
def read_json_file(path_to_file):
    with open(path_to_file) as p:
        rows=[json.loads(line) for line in p]
    return rows

# %%
import pandas as pd

data=[]
for path in files:
    data.extend(read_json_file(path))

df = pd.DataFrame(data)

# %%
df=df.dropna(subset=['section'])
df=df.reset_index(drop=True)

# %%
df.drop(['naver_url','org_url'], axis = 1, inplace = True)

# %%
article=df['article'][10].replace('▶','\n▶').replace('\t', '').replace('\n', ' ')#.split('\n')
article
# Out:
# '      【이슬라마바드=AP/뉴시스】김재영 기자 = 파키스탄에서 2013년 한 해 동안 324 차례의 폭탄 공격으로 최소 1532명이 사망하고 4094명이 부상을 당했다고 1일 언론이 정부 자료를 인용해 보도했다.    이 중 자살 폭탄 공격은 39회 있었으며 이로 해서 764명이 목숨을 잃었다.    직전 2012년에는 395회의 폭탄 공격으로 1007명이 사망해, 1년 사이에 사망자가 53% 급증했다.   폭발 회수로 보면 키베르 파크툰카와 주가 96회로 가장 많이 공격 받았고 아프간 접경의 북서부 주들인 발로치스탄, 신드 및 푼잡이 뒤따랐다.   대부분의 폭탄은 차량이나 도로변에 매설된 후 원격 조종으로 폭파됐으며 파키스탄 탈레반 조직이 공격의 대부분을 행했다고 주장했다.    kjy@newsis.com  ★ 뉴시스 뉴스, 이젠 네이버 뉴스 스탠드에서도 만나세요  ★ 손 안에서 보는 세상, 모바일 뉴시스      '

# %%
import re

#article = re.sub(r'[a-zA-Z0-9]+@newsis.com(.*)', '', article)
article = re.sub(r'\【[a-zA-Z가-힣· ]+\=[a-zA-Z가-힣/ ]+\】[a-zA-Z가-힣· ]+ =|\【[a-zA-Z가-힣· ]+\=[a-zA-Z가-힣/ ]+\】|\<< [a-zA-Z가-힣· ]+\=[a-zA-Z가-힣· ]+ >>|\([a-zA-Z가-힣0-9·, ]+\=[a-zA-Z가-힣· ]+\)|\[[a-zA-Z가-힣·= ]+[자료사진 ]\]|\(연합뉴스 DB\)|\[[a-zA-Z가-힣 ]+제공\]|\[[a-zA-Z가-힣 ]+제공=연합뉴스\]', '', article)
article = re.sub(r'(20[0-9 ]+\.[0-9 ]+\.[0-9 ]+\.)(.*)', '', article)
article = re.sub(r'([a-z.0-9]+@newsis.com)(.*)', '', article)
article
# Out:
# '       파키스탄에서 2013년 한 해 동안 324 차례의 폭탄 공격으로 최소 1532명이 사망하고 4094명이 부상을 당했다고 1일 언론이 정부 자료를 인용해 보도했다.    이 중 자살 폭탄 공격은 39회 있었으며 이로 해서 764명이 목숨을 잃었다.    직전 2012년에는 395회의 폭탄 공격으로 1007명이 사망해, 1년 사이에 사망자가 53% 급증했다.   폭발 회수로 보면 키베르 파크툰카와 주가 96회로 가장 많이 공격 받았고 아프간 접경의 북서부 주들인 발로치스탄, 신드 및 푼잡이 뒤따랐다.   대부분의 폭탄은 차량이나 도로변에 매설된 후 원격 조종으로 폭파됐으며 파키스탄 탈레반 조직이 공격의 대부분을 행했다고 주장했다.    '

# %%
import re
def remove_extras(article):
    #return_article = ''
    article = re.sub(r'\/\/[a-zA-Z가-힣 \n]+|{}|_flash_removeCallback\(\)', '', article)
    article = article.replace('▶','\n▶').replace('\t', '').replace('\n', ' ')
    #remove by line
    article = re.sub(r'\【[a-zA-Z가-힣·\(\) ]+\=[a-zA-Z가-힣\/ ]+\】[a-zA-Z가-힣·\/ ]+ =|\【[a-zA-Z가-힣·\(\)\/ ]+\=[a-zA-Z가-힣\/ ]+\】|\<< [a-zA-Z가-힣· ]+\=[a-zA-Z가-힣· ]+ >>|\([a-zA-Z가-힣0-9·, ]+\=[a-zA-Z가-힣· ]+\)|\[[a-zA-Z가-힣·= ]+[자료사진 ]\]|\(연합뉴스 DB\)|\[[a-zA-Z가-힣 ]+제공\]|\[[a-zA-Z가-힣 ]+제공=연합뉴스\]', '', article)
    #remove copyrithgs
    #article = article.replace('<저작권자(c) 연합뉴스, 무단 전재-재배포 금지>', '')
    #remove email
    #article = re.sub(r'[a-zA-Z0-9_-]+@[a-z]+.[a-z]+.[a-z]+', '', article)
    #remove tail
    
    #for sentence in article.split('\n'):
    #    if not sentence.startswith('▶') : return_article += sentence

    #return_article = return_article.replace('\n', ' ')
    article = re.sub(r'(20[0-9 ]+\.[0-9 ]+\.[0-9 ]+\.)(.*)', '', article)
    article = re.sub(r'([a-z.0-9]+@newsis.com)(.*)', '', article)

    return article

# %%
df['article'][5]
# Out:
# '\n\n\n\n\n\t\n\t【서울=뉴시스】박성환 기자 = 경찰이 체포된 철도노조 간부 1명에 대해 구속영장을 신청했다. \n\n 서울 남대문경찰서는 전날 체포한 철도노조 서울 고속기관차지부장 최모(51)씨에 대해 업무방해 혐의로 구속영장을 신청했다고 1일 밝혔다.\n\n 경찰은 또 전날 충북 제천경찰서에 자진 출석한 철도노조 제천지부장 최모(44)씨와 천안 서부경찰서에 체포된 천안기관차지부장 최모(47)씨에 대해서도 구속영장을 신청할 방침이다. \n\n 경찰 관계자는 "최장기 불법파업을 주도해 사안이 심각하고 도망칠 우려가 높아 구속영장을 신청했다"고 말했다. \n\n 경찰은 이날 현재까지 모두 35명에 대한 체포영장을 발부받아 6명을 체포했다. 이 중 경북영주본부 소속 간부 윤모(47)씨와 대전본부 조직국장 고모(45)씨 등 2명을 구속했다.\n\n sky0322@newsis.com \n\n★ 뉴시스 뉴스, 이젠 네이버 뉴스 스탠드에서도 만나세요\n\n★ 손 안에서 보는 세상, 모바일 뉴시스\n\n\n\n\n\n'

# %%
print(remove_extras(df['article'][18]))
# Out:
#           김정태 하나금융지주 회장은 올해 '변화'와 '실행'을 통해 시장 주도권을 잡자고 임직원들에게 당부했다.    김 회장은 1일 신년사를 통해 "금융회사가 혁신을 도입하지 못하면 회사의 생존여부를 장담할 수 없게 됐다"면서 이 같이 밝혔다.    그는 급변하는 금융 트렌드에 대응하면서 시장을 선도해 나가려면 영업방식과 업권의 경계를 뛰어넘는 금융서비스, 글로벌 마케팅을 변화시켜야 한다고 강조했다.    그는 또 변화를 이뤄내기 위해서는 "즉시 실행하는 것"이 중요하다고 지적했다.    김 회장은 "고민과 검토를 통해서 방향이 정해졌다면 주저없이 실천해야 한다. 미루지 않고 바로 실행하는 습관이 성공을 이끈다"고 말했다.    다음은 신년사 전문.    갑오(甲午)년 새해가 밝았습니다. 2014년은 푸른 말 즉, 청마(靑馬)의 해입니다. 성공이 말 달리듯 온다라는 뜻인 '마도성공(馬到成功)'이라는 옛말처럼 올 한해 청마의 건강하고 힘찬 기운이 하나가족 모두에게 가득하기를 기원합니다.    지난 2013년 하나금융그룹은 새로운 도약, 버전 3.01을 위한 기반을 다졌습니다. 외환은행이 완전하게 그룹의 한 가족이 됐고, 교포은행 중 유일하게 미국 연방 라이센스를 가지고 있는 BNB은행이 역시 하나금융의 일원이 되어 그룹의 글로벌 영업기반을 확대했습니다. 이런 노력을 발판으로 하나금융그룹이 아시안 뱅커(Asian Banker)지로부터 '한국 최우량 금융기관상'을 수상하는 등 대외적으로 그룹의 가치와 실력을 인정받았습니다.    우리는 2008년 글로벌 금융위기 이후 자본주의의 패러다임이 바뀌는 것을 경험하고 있습니다. 금융에 대한 사회의 요구가 계속 커지고 규제도 갈수록 강화되고 있습니다. 경제위기 이후 조성된 저성장 저마진의 국면은 그 끝을 알 수 없습니다. 2014년도 경제성장률이 3%대에 그칠 것으로 예상되고, 국내 기업 80%의 경영기조가 긴축 내지는 현상 유지입니다. 말 그대로 위기가 계속되고 있습니다.    그러나 더 심각한 것은 금융의 트렌드가 바뀌고 있는 현실입니다. 소셜미디어와 IT 기술의 발전으로 소비자들의 구매패턴과 행동이 급변하고 있습니다. 시장 자체가 바뀌는 것입니다. 음반시장, 서적시장 등이 온라인 중심으로 재편된 것처럼 금융업도 근본적인 변화에 직면할 것입니다. '뱅크 3.0'에서는 고객과 금융기관의 상호작용 중 모바일을 통한 접촉은 월 20-30회에 이를 것이지만, 영업점을 통한 거래는 '월'이 아닌 '연간' 2-3회에 그칠 것으로 보고 있습니다. 금융회사가 혁신을 도입하지 못하면 회사의 생존여부를 장담할 수 없게 됐습니다.    잠시 우리를 돌아봅시다. 하나금융은 국내 최초로 모바일뱅킹을 시작하는 등 시장의 변화와 혁신을 선도하며 대외적으로도 성과와 위상을 인정받았습니다. 그러나 조직 구성과 마케팅 방식, 보다 중요한 생각은 그대로 머물러 있는 듯 합니다. 금융의 흐름, 그 자체가 바뀌고 있습니다. 갈 길을 서둘러야 합니다. 시장의 변화를 내다보고 발빠르게 대응하는 것이 필요합니다. '국면'이 바뀌는 이 시점이 새로운 기회입니다. 시장을 선도하기 위해 다음 몇 가지를 당부드리고자 합니다.    첫째, '판'을 바꿀 수 있는 아이디어를 고민해야 합니다. 기존의 방식으로는 절대로 현재와 달라질 수 없습니다. 스마트금융, 모바일 신용카드 등에서 우리가 새로운 국면을 만들어냈던 것처럼 그룹의 모든 업종에서 그런 변화를 계속 만들어내야 합니다.    둘째, 영업방식 또한 본질적인 변화가 필요합니다. 예를 들어 고객을 '가계'와 '기업'으로 분리했던 것은 앞으로의 금융환경에서는 맞지 않습니다. 기본적으로 고객은 '가계'와 '기업'을 통해 서로 연결돼있습니다. 양 쪽의 시너지와 빅데이타를 활용한 행동분석 등을 통해 고객 확대에 주력해야 합니다.    셋째, 업권의 경계를 뛰어넘는 금융서비스를 만들어야 합니다. 고객이 원하는 상품은 이미 업종 구분이 없습니다. 다른 금융회사 뿐만 아니라 다른 업종의 회사가 경쟁 상대가 될 것입니다.   마지막으로 그룹의 글로벌 마케팅도 변화를 만들어내야 합니다. 이미 하나금융은 국내 최대의 글로벌 네트워크를 보유하고 있습니다. 글로벌 시너지와 성과를 최고로 만들기 위한 노력이 더욱 절실합니다. 향후 글로벌 사업비중을 국내와 버금갈 정도로 키우기 위한 시스템을 만들어내야 합니다.    '변화'를 이뤄내기 위해 무엇보다 중요한 것은 '실행'입니다. 흔히 '성과'를 '역량'과 '실행'의 곱으로 표현하곤 합니다. 아무리 지식이나 아이디어가 뛰어나더라도 실행이 없다면 성과는 0(zero)가 됩니다. 저성장 저마진의 뉴노멀 시대에서 금융회사들은 외형이 아니라 수익, 리스크 관리, 고객 등 본질적인 성과로 경쟁을 하게 될 것입니다. 새로운 3.0 시대를 시작하는 우리도 내실을 키우는 유기적인 성장에 집중할 때 입니다. 이럴 때 가장 중요한 것이 성과를 만들어내는 실행의 힘입니다.    여기에 저는 '즉시'라는 단어를 더 하고 싶습니다. 고민과 검토를 통해서 방향이 정해졌다면 주저없이 실천하는 것이 중요합니다. 부자들의 생활습관을 연구한 한 설문조사에 따르면 성공한 백만장자들은 질문지에 회신하는 속도 자체가 빨랐다고 합니다. 미루지 않고 바로 실행하는 습관이 그들을 성공으로 이끌었던 겁니다. '나중에 해야지', '언젠가 하겠지'하는 것은 실행하지 않겠다는 또 다른 표현입니다. 실천하기 가장 좋은 날은 '오늘'이고, 가장 좋은 시간은 바로 '지금'입니다.    살아가는 방법에 대해 누군가 물어올 때 저는 연극에 곧잘 비유를 합니다. 우리 삶도 배우가 배역을 수행하는 것과 같습니다. 모든 힘을 쏟는 열정의 연기가 연극을 빛나게 하듯, 우리에게 주어진 역할에서 최고의 노력을 다할 때 진정한 보람과 성취를 얻을 수 있습니다. 새해 아침, 우리에게 주어진 배역이 무엇인지 그리고 열정을 다하고 있는지 다시 한번 생각해 봅시다. 실행의 힘은 바로 그런 마음가짐에서 시작됩니다.    자랑스러운 하나금융 가족 여러분. 작년 우리는 함께 그룹의 새로운 비전을 만들었습니다. 위기를 극복하고 새로운 방향을 알려주는 하나금융의 나침반이 될 것입니다. 임직원들이 직접 참여해 스스로 만든 비전이라는 점이 무엇보다도 자랑스럽습니다. 곧 있을 '출발 2014 행사'를 통해 2만3000여 명 하나금융 가족 모두와 그 내용을 함께 하겠습니다.    '등고망원(登高望遠)', 높이 올라서 멀리 봐야한다는 뜻입니다. 또 시대 흐름에 맞게 앞으로 나아간다는 '여시구진(與時俱進)'이라는 말도 있습니다. 올해 우리의 가야할 길을 잘 요약해주는 화두입니다. 하나금융의 미래를 항상 가슴에 담고, 시대 변화에 맞게 우리를 바꾸어가야 합니다. 여러분 조금 더 멀리 바라봅시다. 그리고 변화에 맞춰 함께 나아갑시다.    120년 전 '갑오경장'이 있었습니다. 조선의 체제 변화를 위해 시도한 혁신이었으나 성공하지 못했습니다. 그 후 국력이 쇠약해진 역사의 교훈은 우리 모두가 잘 알고 있습니다. 하지만 하나금융에게 올해 갑오년은 다를 것입니다. 우리는 등고망원과 여시구진의 정신으로 반드시 성공하는 한 해로 만들 것입니다. 역사는 하나금융그룹의 미래를 연 '성공의 갑오경장'으로 기록할 것입니다.

# %%
df['article'].apply(lambda x: remove_extras(x))
# Out:
# 0                   2014년 갑오년(甲午年) 청마의 해가 밝아오며 제주시 조천읍 제...
# 1                  새해를 맞은 1일 베이징의 밀레니엄 기념비에 '베이징의 빛'으로 불...
# 2                  조지 H.W. 부시 전 미 대통령의 부인 바버라 부시 여사가 지난달...
# 3                   2014년 갑오년(甲午年) 청마의 해가 밝아오며 제주시 조천읍 제...
# 4                  파리 시민들이 1일 새해를 맞아 화려하게 장식된 샹제리제 거리를 가...
# 5                경찰이 체포된 철도노조 간부 1명에 대해 구속영장을 신청했다.    서...
# 6                   2014년 갑오년(甲午年) 청마의 해가 밝아오며 제주시 조천읍 제...
# 7                  새해를 하루 앞둔 31일 브라질 리우데자네이루의 코파카바나 해변에 ...
# 8                   2014년 갑오년(甲午年) 청마의 해가 밝아오며 제주시 조천읍 제...
# 9                   2014년 갑오년(甲午年) 청마의 해가 밝아오며 제주시 조천읍 제...
# 10               파키스탄에서 2013년 한 해 동안 324 차례의 폭탄 공격으로 최소 ...
# 11               박선희 새누리당 경기 안산시 상록갑 당협위원장은 "대학생과 젊은이들은 ...
# 12                  2014년 갑오년(甲午年) 청마의 해가 밝아오며 제주시 조천읍 제...
# 13                 권오성 육군참모총장이 2014년 갑오년 새해 아침 국립대전현충원을 ...
# 14              금융권 최고경영자(CEO)들은  2014년 갑오년에는 내실을 다지는데 주...
# 15                 새해맞이를 위해 31일 뉴욕 타임스스퀘어에 모인 사람들이 2014를...
# 16                 프란치스코 교황이 31일(현지시간) 바티칸의 성베드로 성당에서 송년...
# 17                  2014년도 예산안 심의과정에서 으르렁거리던 여야가 1일 예산 통...
# 18                  김정태 하나금융지주 회장은 올해 '변화'와 '실행'을 통해 시장 ...
# 19            1일 오후 서울 잠실실내체육관에서 열린 2013-2014 KB국민카드 프로농...
# 20                  1일 오후 민주노총이 위치한 서울 중구 정동 경향신문사 앞에서 시...
# 21                ◇5급 승진  ▲보건행정과장 김상현 ▲풍천면장 김대현  ◇5급 전보 ...
# 22                  1일 오후 민주노총이 위치한 서울 중구 정동 경향신문사 앞에서 시...
# 23                  2014년 갑오년(甲午年) 청마의 해가 밝아오며 제주시 조천읍 제...
# 24                 ▲교무처장 겸 e-러닝지원 센터장 염태호 ▲경상대학장 겸 경영경제연...
# 25                  2014년 갑오년(甲午年) 청마의 해가 밝아오며 제주시 조천읍 제...
# 26                  서울시는 1일 대기상태 악화에 따라 이날 오후 10시를 기해 서울...
# 27                  1일 오후 민주노총이 위치한 서울 중구 정동 경향신문사 앞에서 시...
# 28               인도와 파키스탄은 1일 상대방의 핵 시설 공격을 금지한 1988년 협정...
# 29                  1일 오후 민주노총이 위치한 서울 중구 정동 경향신문사 앞에서 시...
#                                 ...
# 672858              광주 동부경찰서는 1일 광주 동구 지산동 지산사거리와 법원 사이에...
# 672859              1일 오후 세종시 정부세종청사 6동 대강당에서 열린 해양수산부 월...
# 672860              1일 오후 세종시 정부세종청사 6동 대강당에서 열린 해양수산부 월...
# 672861              1일 오후 세종시 정부세종청사 6동 대강당에서 열린 해양수산부 월...
# 672862            새누리당 김무성 대표와 이완구 원내대표가 1일 오후 서울 여의도 국회...
# 672863              1일 오후 세종시 정부세종청사 6동 대강당에서 열린 해양수산부 월...
# 672864           일본 연구팀은 한 기생충 감염이 오히려 아토피성 피부염(AD) 증상을 ...
# 672865              1일 경북 문경시 실내체육관에서 열린 제52회 경북도민체전 폐막식...
# 672866              1일 경북 문경시 실내체육관에서 열린 제52회 경북도민체전 폐막식...
# 672867              1일 오후 세종시 정부세종청사 6동 대강당에서 열린 해양수산부 월...
# 672868              1일 경북 문경시 실내체육관에서 열린 제52회 경북도민체전 폐막식...
# 672869              1일 경북 문경시 실내체육관에서 열린 제52회 경북도민체전 폐막식...
# 672870            1일 오후 강원 춘천시 강원도청앞에서 강원지역 농민, 진보 시민·사회...
# 672871              1일 오후 세종시 정부세종청사 6동 대강당에서 열린 해양수산부 월...
# 672872          공포탄 아닌 실탄 2발 쏴 총상…총기 사용 규정 위반   경찰이 실탄을 ...
# 672873              1일 오후 세종시 정부세종청사 6동 대강당에서 열린 해양수산부 월...
# 672874              1일 오후 세종시 정부세종청사 6동 대강당에서 열린 해양수산부 월...
# 672875           버락 오바마 미 대통령은 오는 11월 중간선거의 최대 관건인 상원의 여...
# 672876              1일 오후 세종시 정부세종청사 6동 대강당에서 열린 해양수산부 월...
# 672877           휴일 아침 방배동 주택가에서 흉기를 들고 난동을 부리던 30대 여성에게...
# 672878             ▲노승락 홍천군수는 9월2일 오후 6시 강릉여성수련원에서 실시되는 ...
# 672879           북한이 1일 자신들이 억류하고 있는 미국인 3명에 대해 외국 언론과의 ...
# 672880             ◇지방소방위   ▲방호구조과 김동진 ▲방호구조과 전창규 ▲방호구조과...
# 672881              1일 오후 세종시 정부세종청사 6동 대강당에서 열린 해양수산부 월...
# 672882           강원도선거관리위원회는 1일 삼척시가 원전 유치 철회를 위한 주민투표 사...
# 672883             ▲최문순 강원도지사는 2일 오전 10시 철원군청에서 열리는 이전기업...
# 672884            정의화 국회의장이 1일 오후 서울 여의도 국회를 방문한 요십 레코(J...
# 672885           강원 강릉원주대학교(총장 전방욱)는 ㈜LG유플러스 중부법인영업단(단장 ...
# 672886           영화배우 이병헌(44)씨와 함께 찍은 영상을 인터넷에 유포하겠다며 협박...
# 672887              1일 경북 구미 금오산호텔에서 열린 제16회 한중일 지방정부 교류...
# Name: article, dtype: object

# %%
df['article'][18]
# Out:
# '\n\n\n\n\n\n\n\n\n【서울=뉴시스】정리/변해정 기자 = 김정태 하나금융지주 회장은 올해 \'변화\'와 \'실행\'을 통해 시장 주도권을 잡자고 임직원들에게 당부했다. \n\n 김 회장은 1일 신년사를 통해 "금융회사가 혁신을 도입하지 못하면 회사의 생존여부를 장담할 수 없게 됐다"면서 이 같이 밝혔다. \n\n 그는 급변하는 금융 트렌드에 대응하면서 시장을 선도해 나가려면 영업방식과 업권의 경계를 뛰어넘는 금융서비스, 글로벌 마케팅을 변화시켜야 한다고 강조했다. \n\n 그는 또 변화를 이뤄내기 위해서는 "즉시 실행하는 것"이 중요하다고 지적했다. \n\n 김 회장은 "고민과 검토를 통해서 방향이 정해졌다면 주저없이 실천해야 한다. 미루지 않고 바로 실행하는 습관이 성공을 이끈다"고 말했다. \n\n 다음은 신년사 전문. \n\n 갑오(甲午)년 새해가 밝았습니다. 2014년은 푸른 말 즉, 청마(靑馬)의 해입니다. 성공이 말 달리듯 온다라는 뜻인 \'마도성공(馬到成功)\'이라는 옛말처럼 올 한해 청마의 건강하고 힘찬 기운이 하나가족 모두에게 가득하기를 기원합니다. \n\n 지난 2013년 하나금융그룹은 새로운 도약, 버전 3.01을 위한 기반을 다졌습니다. 외환은행이 완전하게 그룹의 한 가족이 됐고, 교포은행 중 유일하게 미국 연방 라이센스를 가지고 있는 BNB은행이 역시 하나금융의 일원이 되어 그룹의 글로벌 영업기반을 확대했습니다. 이런 노력을 발판으로 하나금융그룹이 아시안 뱅커(Asian Banker)지로부터 \'한국 최우량 금융기관상\'을 수상하는 등 대외적으로 그룹의 가치와 실력을 인정받았습니다. \n\n 우리는 2008년 글로벌 금융위기 이후 자본주의의 패러다임이 바뀌는 것을 경험하고 있습니다. 금융에 대한 사회의 요구가 계속 커지고 규제도 갈수록 강화되고 있습니다. 경제위기 이후 조성된 저성장 저마진의 국면은 그 끝을 알 수 없습니다. 2014년도 경제성장률이 3%대에 그칠 것으로 예상되고, 국내 기업 80%의 경영기조가 긴축 내지는 현상 유지입니다. 말 그대로 위기가 계속되고 있습니다. \n\n 그러나 더 심각한 것은 금융의 트렌드가 바뀌고 있는 현실입니다. 소셜미디어와 IT 기술의 발전으로 소비자들의 구매패턴과 행동이 급변하고 있습니다. 시장 자체가 바뀌는 것입니다. 음반시장, 서적시장 등이 온라인 중심으로 재편된 것처럼 금융업도 근본적인 변화에 직면할 것입니다. \'뱅크 3.0\'에서는 고객과 금융기관의 상호작용 중 모바일을 통한 접촉은 월 20-30회에 이를 것이지만, 영업점을 통한 거래는 \'월\'이 아닌 \'연간\' 2-3회에 그칠 것으로 보고 있습니다. 금융회사가 혁신을 도입하지 못하면 회사의 생존여부를 장담할 수 없게 됐습니다. \n\n 잠시 우리를 돌아봅시다. 하나금융은 국내 최초로 모바일뱅킹을 시작하는 등 시장의 변화와 혁신을 선도하며 대외적으로도 성과와 위상을 인정받았습니다. 그러나 조직 구성과 마케팅 방식, 보다 중요한 생각은 그대로 머물러 있는 듯 합니다. 금융의 흐름, 그 자체가 바뀌고 있습니다. 갈 길을 서둘러야 합니다. 시장의 변화를 내다보고 발빠르게 대응하는 것이 필요합니다. \'국면\'이 바뀌는 이 시점이 새로운 기회입니다. 시장을 선도하기 위해 다음 몇 가지를 당부드리고자 합니다. \n\n 첫째, \'판\'을 바꿀 수 있는 아이디어를 고민해야 합니다. 기존의 방식으로는 절대로 현재와 달라질 수 없습니다. 스마트금융, 모바일 신용카드 등에서 우리가 새로운 국면을 만들어냈던 것처럼 그룹의 모든 업종에서 그런 변화를 계속 만들어내야 합니다. \n\n 둘째, 영업방식 또한 본질적인 변화가 필요합니다. 예를 들어 고객을 \'가계\'와 \'기업\'으로 분리했던 것은 앞으로의 금융환경에서는 맞지 않습니다. 기본적으로 고객은 \'가계\'와 \'기업\'을 통해 서로 연결돼있습니다. 양 쪽의 시너지와 빅데이타를 활용한 행동분석 등을 통해 고객 확대에 주력해야 합니다. \n\n 셋째, 업권의 경계를 뛰어넘는 금융서비스를 만들어야 합니다. 고객이 원하는 상품은 이미 업종 구분이 없습니다. 다른 금융회사 뿐만 아니라 다른 업종의 회사가 경쟁 상대가 될 것입니다.\n\n 마지막으로 그룹의 글로벌 마케팅도 변화를 만들어내야 합니다. 이미 하나금융은 국내 최대의 글로벌 네트워크를 보유하고 있습니다. 글로벌 시너지와 성과를 최고로 만들기 위한 노력이 더욱 절실합니다. 향후 글로벌 사업비중을 국내와 버금갈 정도로 키우기 위한 시스템을 만들어내야 합니다. \n\n \'변화\'를 이뤄내기 위해 무엇보다 중요한 것은 \'실행\'입니다. 흔히 \'성과\'를 \'역량\'과 \'실행\'의 곱으로 표현하곤 합니다. 아무리 지식이나 아이디어가 뛰어나더라도 실행이 없다면 성과는 0(zero)가 됩니다. 저성장 저마진의 뉴노멀 시대에서 금융회사들은 외형이 아니라 수익, 리스크 관리, 고객 등 본질적인 성과로 경쟁을 하게 될 것입니다. 새로운 3.0 시대를 시작하는 우리도 내실을 키우는 유기적인 성장에 집중할 때 입니다. 이럴 때 가장 중요한 것이 성과를 만들어내는 실행의 힘입니다. \n\n 여기에 저는 \'즉시\'라는 단어를 더 하고 싶습니다. 고민과 검토를 통해서 방향이 정해졌다면 주저없이 실천하는 것이 중요합니다. 부자들의 생활습관을 연구한 한 설문조사에 따르면 성공한 백만장자들은 질문지에 회신하는 속도 자체가 빨랐다고 합니다. 미루지 않고 바로 실행하는 습관이 그들을 성공으로 이끌었던 겁니다. \'나중에 해야지\', \'언젠가 하겠지\'하는 것은 실행하지 않겠다는 또 다른 표현입니다. 실천하기 가장 좋은 날은 \'오늘\'이고, 가장 좋은 시간은 바로 \'지금\'입니다. \n\n 살아가는 방법에 대해 누군가 물어올 때 저는 연극에 곧잘 비유를 합니다. 우리 삶도 배우가 배역을 수행하는 것과 같습니다. 모든 힘을 쏟는 열정의 연기가 연극을 빛나게 하듯, 우리에게 주어진 역할에서 최고의 노력을 다할 때 진정한 보람과 성취를 얻을 수 있습니다. 새해 아침, 우리에게 주어진 배역이 무엇인지 그리고 열정을 다하고 있는지 다시 한번 생각해 봅시다. 실행의 힘은 바로 그런 마음가짐에서 시작됩니다. \n\n 자랑스러운 하나금융 가족 여러분. 작년 우리는 함께 그룹의 새로운 비전을 만들었습니다. 위기를 극복하고 새로운 방향을 알려주는 하나금융의 나침반이 될 것입니다. 임직원들이 직접 참여해 스스로 만든 비전이라는 점이 무엇보다도 자랑스럽습니다. 곧 있을 \'출발 2014 행사\'를 통해 2만3000여 명 하나금융 가족 모두와 그 내용을 함께 하겠습니다. \n\n \'등고망원(登高望遠)\', 높이 올라서 멀리 봐야한다는 뜻입니다. 또 시대 흐름에 맞게 앞으로 나아간다는 \'여시구진(與時俱進)\'이라는 말도 있습니다. 올해 우리의 가야할 길을 잘 요약해주는 화두입니다. 하나금융의 미래를 항상 가슴에 담고, 시대 변화에 맞게 우리를 바꾸어가야 합니다. 여러분 조금 더 멀리 바라봅시다. 그리고 변화에 맞춰 함께 나아갑시다. \n\n 120년 전 \'갑오경장\'이 있었습니다. 조선의 체제 변화를 위해 시도한 혁신이었으나 성공하지 못했습니다. 그 후 국력이 쇠약해진 역사의 교훈은 우리 모두가 잘 알고 있습니다. 하지만 하나금융에게 올해 갑오년은 다를 것입니다. 우리는 등고망원과 여시구진의 정신으로 반드시 성공하는 한 해로 만들 것입니다. 역사는 하나금융그룹의 미래를 연 \'성공의 갑오경장\'으로 기록할 것입니다. \n\n hjpyun@newsis.com\n\n★ 뉴시스 뉴스, 이젠 네이버 뉴스 스탠드에서도 만나세요\n\n★ 손 안에서 보는 세상, 모바일 뉴시스\n\n\n\n\n\n'

# %%
df['article']=df['article'].apply(lambda x: remove_extras(x))

# %%
counts=df.groupby('section').size()
sorted_counts=counts.sort_values(ascending=False)

# %%
sorted_counts
# Out:
# section
# 사회|사회일반        155140
# 정치|정치일반         65072
# 경제|경제일반         45058
# 전국|강원           23019
# 스포츠|스포츠일반       21357
# 스포츠|야구/MLB      19867
# 전국|대구/경북        19291
# 전국|대전/충남        16329
# 스포츠|축구          14989
# 연예|연예일반         14712
# 사회|사건/사고        14542
# 국제|미주           13875
# 전국|충북           13855
# 정치|행정           12577
# 국제|유럽           12207
# 경제|산업/기업        12071
# 전국|전북           10403
# 정치|국방/외교/북한      9454
# 전국|경기남부          9113
# 스포츠|농구           8994
# 전국|광주/전남         8944
# 국제|아시아/대양주       8921
# 사회|교육/취업/노동      8279
# 전국|울산            8277
# 전국|부산            8130
# 전국|제주            7950
# 전국|서울            7611
# 정치|청와대           7356
# 전국|경남            6880
# 사회|법원/검찰         6701
#                 ...
# 경제|농수축산           380
# 사회|수능             378
# 국제|국제기구           274
# 문화|문학             239
# 문화|생활             234
# 경제|CEO            210
# 기타|그래픽            207
# 연예|미디어            174
# 문화|문화계            123
# 경제|창업/취업          119
# 경제|증권             118
# 사람들|동정             87
# 연예|만화              51
# 라이프|생활             50
# 오피니언|기자수첩          47
# 오피니언|크로스로드         38
# 라이프|여행레저           31
# 연예|해외연예            29
# 오피니언|기고            22
# 경제|단신              16
# 사람들|인터뷰            16
# 경제|기업 실적           14
# 경제|국제경제            10
# 오피니언|데스크창          10
# 사람들|이 사람            4
# 오피니언|포럼·세미나         3
# 경제|종목토크             1
# 라이프|패션/뷰티           1
# 산업|유통/생활경제          1
# 사람들|본사손님            1
# dtype: int64

# %%
df.to_pickle('newsis_2014.pkl')

# %% [markdown]
# ### Compare Memory Usage
#
# ```
# df['article']=pd.Series([val for val in df['article'].str.replace(r'\r|\t|\n|\/\/[a-zA-Z가-힣 \n]+|{}|_flash_removeCallback\(\)|[a-zA-Z0-9]+@yonhapnews.co.kr|\[연합뉴스[a-zA-Z가-힣 ]+\]|\([a-zA-Z가-힣· ]+\=연합뉴스\)|\[[a-zA-Z가-힣 ]+\=연합뉴스\]|[a-zA-Z가-힣 ]+ 기자 \=|[a-zA-Z가-힣 ]+ 특파원 \=','')])
# ```
#
# ```
# df['article']=df['article'].str.replace(r'\[연합뉴스[a-zA-Z가-힣 ]+\]|\([a-zA-Z가-힣· ]+\=연합뉴스\)|\[[a-zA-Z가-힣 ]+\=연합뉴스\]|[a-zA-Z가-힣 ]+ 기자 \=|[a-zA-Z가-힣 ]+ 특파원 \=','')
# ```

# %%
df.memory_usage(deep=True)
# Out:
# Index              80
# article    1091547668
# author      112432385
# date         50537779
# section      78009964
# title       118746873
# dtype: int64
