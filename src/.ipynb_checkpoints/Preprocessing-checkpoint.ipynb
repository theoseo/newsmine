# %%
import rds_config
from sqlalchemy import create_engine

#rds settings
db_host  = rds_config.db_host
db_username = rds_config.db_username
db_password = rds_config.db_password
db_name = rds_config.db_name

#한글 깨짐 현상 해결
#http://yongho1037.tistory.com/570
SQLALCHEMY_DATABASE_URI = 'mysql+pymysql://' + db_username + ':' + db_password + '@' + db_host + '/' + db_name + '?charset=utf8'

engine = create_engine(SQLALCHEMY_DATABASE_URI)
connection = engine.connect()

# %%
import pandas as pd
sql = "SELECT date, substring(date, 6,2) as month, media, title, org_count, naver_count, org_count+naver_count as total_count, section FROM newscrawl WHERE org_count>0 or naver_count>0 "
df = pd.read_sql(sql, connection)
#pd.read_csv("dcdata10.csv")

# %%
len(df)
# Out:
# 451156

# %%
df['title']=df['title'].str.replace(r'\[[A-Za-z가-힣0-9 ]+\]|\([A-Za-z가-힣0-9 ]+\)|\<[A-Za-z가-힣0-9 ]+\>','')

# %%
# %%time
from konlpy.tag import Mecab
mecab = Mecab()

def mecab_words(sentence):
    word_list = mecab.nouns(sentence)
    #return " ".join(word_list)
    return " ".join(filter(lambda x: len(x)>1, word_list))
    #return filter(lambda x: len(x)>1, " ".join(word_list))

df['title_me_noun'] = df['title'].apply(mecab_words)
# Out:
# CPU times: user 36.1 s, sys: 64 ms, total: 36.1 s
# Wall time: 36.1 s

# %%
df_by_month = df.groupby(['month'])
df_by_media_month = df.groupby(['month', 'media'])

# %%
from collections import Counter

by_me_month = df_by_month['title_me_noun'].apply(list)
result_by_me_month = pd.Series()

for month, words in by_me_month.iteritems():
    result_by_me_month.set_value(month, Counter(" ".join(words).split(" ")))

# %%
for month, words in result_by_me_month.iteritems():
    print(month, words.most_common(50))
# Out:
# 01 [('한국', 1127), ('대통령', 905), ('중국', 822), ('서울', 685), ('위안부', 670), ('경제', 670), ('더민주', 649), ('정부', 621), ('시장', 597), ('세계', 584), ('북한', 582), ('논란', 570), ('안철수', 521), ('미국', 506), ('한파', 460), ('의원', 452), ('일본', 442), ('가능', 439), ('정치', 425), ('기업', 415), ('청년', 406), ('공항', 402), ('공개', 394), ('사망', 391), ('합의', 387), ('올해', 384), ('영입', 383), ('우리', 382), ('핵실험', 381), ('영상', 376), ('제주', 369), ('경찰', 368), ('대북', 368), ('대표', 361), ('탈당', 348), ('제재', 346), ('여성', 346), ('총선', 339), ('새해', 338), ('누리', 333), ('국회', 333), ('김종인', 323), ('이유', 314), ('김무성', 313), ('최고', 310), ('지원', 309), ('조선', 309), ('개발', 305), ('문재인', 304), ('사람', 303)]
# 02 [('한국', 906), ('개성공단', 765), ('대통령', 732), ('중국', 678), ('사드', 665), ('정부', 662), ('북한', 652), ('미사일', 649), ('서울', 558), ('기업', 542), ('더민주', 531), ('시장', 529), ('세계', 505), ('가능', 489), ('필리버스터', 471), ('제재', 471), ('논란', 455), ('경제', 455), ('의원', 446), ('발사', 444), ('공천', 420), ('배치', 419), ('대북', 418), ('총선', 412), ('공개', 383), ('영상', 374), ('시간', 374), ('미국', 372), ('국민의당', 367), ('경찰', 344), ('국회', 343), ('사망', 334), ('우리', 327), ('여성', 323), ('일본', 318), ('지카', 318), ('중단', 314), ('최신', 311), ('정치', 310), ('이유', 309), ('테러방지법', 303), ('연합뉴스', 303), ('최대', 299), ('최고', 296), ('국민', 291), ('테러', 288), ('사람', 282), ('대표', 280), ('후보', 278), ('연휴', 276)]
# 03 [('공천', 1337), ('더민주', 973), ('한국', 966), ('총선', 859), ('김종인', 818), ('후보', 762), ('대통령', 756), ('대표', 686), ('서울', 682), ('유승민', 589), ('이세돌', 588), ('국민의당', 553), ('김무성', 552), ('알파', 543), ('기업', 536), ('여성', 535), ('중국', 516), ('논란', 508), ('새누리', 477), ('세계', 458), ('정부', 452), ('비례', 450), ('야권', 442), ('시장', 436), ('정치', 430), ('경제', 421), ('공개', 416), ('안철수', 414), ('테러', 407), ('일본', 407), ('인공지능', 391), ('북한', 388), ('연대', 378), ('의원', 377), ('제재', 371), ('트럼프', 371), ('경찰', 364), ('선거', 361), ('가능', 341), ('우리', 335), ('영상', 332), ('발표', 332), ('청년', 331), ('사망', 330), ('시간', 325), ('새누리당', 321), ('조사', 320), ('최고', 320), ('최대', 319), ('국민', 315)]
# 04 [('총선', 1080), ('대통령', 1010), ('한국', 920), ('투표', 729), ('정부', 661), ('후보', 656), ('더민주', 654), ('서울', 603), ('기업', 574), ('국민의당', 531), ('선거', 530), ('논란', 525), ('경제', 514), ('새누리', 506), ('세월호', 501), ('대표', 478), ('중국', 443), ('세계', 432), ('구조', 427), ('지진', 423), ('지원', 415), ('김종인', 403), ('시장', 402), ('일본', 396), ('국회', 395), ('여성', 393), ('가능', 391), ('정치', 389), ('조선', 369), ('조사', 360), ('문재인', 359), ('북한', 354), ('안철수', 333), ('사망', 333), ('조정', 330), ('공개', 324), ('우리', 318), ('호남', 314), ('부산', 303), ('연합', 302), ('최대', 296), ('전국', 292), ('영상', 291), ('국민', 286), ('미국', 280), ('의혹', 280), ('교육', 278), ('이유', 276), ('청년', 275), ('어버이', 274)]
# 05 [('한국', 1068), ('대통령', 988), ('여성', 702), ('트럼프', 695), ('정부', 632), ('서울', 623), ('옥시', 566), ('기업', 555), ('국회', 541), ('논란', 531), ('중국', 503), ('세계', 502), ('시장', 450), ('조선', 422), ('구조', 418), ('반기문', 416), ('살인', 414), ('경제', 401), ('가능', 399), ('대회', 381), ('북한', 373), ('경찰', 373), ('조사', 365), ('살균제', 364), ('가습기', 357), ('대표', 357), ('조정', 356), ('공개', 355), ('검찰', 345), ('미세먼지', 339), ('김정은', 338), ('구속', 334), ('우리', 328), ('정치', 328), ('의혹', 318), ('수사', 317), ('시간', 314), ('사망', 311), ('미국', 310), ('사건', 306), ('오바마', 305), ('개발', 304), ('추진', 304), ('이유', 303), ('투자', 299), ('거부', 299), ('사업', 296), ('전국', 295), ('일본', 292), ('최고', 285)]
# 06 [('한국', 1079), ('시장', 747), ('공항', 737), ('정부', 714), ('브렉시트', 704), ('중국', 669), ('서울', 655), ('검찰', 637), ('세계', 627), ('논란', 593), ('기업', 571), ('경찰', 570), ('대통령', 566), ('여성', 555), ('수사', 548), ('조선', 542), ('의원', 524), ('국회', 519), ('사망', 494), ('의혹', 485), ('조사', 473), ('사고', 460), ('성폭행', 443), ('경제', 442), ('국민의당', 429), ('롯데', 422), ('시간', 408), ('영국', 406), ('우리', 393), ('부산', 372), ('구속', 371), ('추진', 371), ('대표', 365), ('테러', 362), ('국민', 362), ('지원', 360), ('미국', 358), ('공개', 357), ('최고', 347), ('가능', 339), ('문제', 339), ('불법', 333), ('세월호', 331), ('사건', 320), ('이유', 319), ('정치', 319), ('국내', 314), ('안전', 313), ('더민주', 308), ('어선', 303)]
# 07 [('사드', 1920), ('한국', 1038), ('대통령', 957), ('경찰', 853), ('배치', 839), ('정부', 742), ('논란', 685), ('서울', 677), ('중국', 630), ('사망', 627), ('성주', 610), ('테러', 587), ('의혹', 537), ('검찰', 537), ('세계', 532), ('의원', 528), ('여성', 514), ('기업', 507), ('조사', 506), ('시장', 494), ('우병우', 487), ('시간', 466), ('수사', 458), ('결정', 456), ('가능', 453), ('포켓몬', 445), ('부산', 431), ('공개', 426), ('총리', 415), ('구속', 414), ('경제', 409), ('폭염', 400), ('미국', 400), ('최고', 400), ('전국', 394), ('대표', 393), ('일본', 383), ('반대', 382), ('사고', 376), ('국회', 372), ('국민', 363), ('이유', 359), ('지원', 342), ('터키', 340), ('조선', 338), ('우리', 336), ('안전', 332), ('트럼프', 329), ('진경준', 326), ('국가', 325)]
# 08 [('사드', 1262), ('대통령', 1068), ('폭염', 1055), ('한국', 1022), ('정부', 741), ('서울', 741), ('중국', 735), ('논란', 620), ('더민주', 582), ('수사', 568), ('대표', 561), ('우병우', 548), ('경찰', 546), ('기업', 505), ('검찰', 498), ('의원', 491), ('여성', 482), ('가능', 474), ('사망', 473), ('세계', 470), ('최고', 461), ('일본', 435), ('청년', 429), ('올림픽', 427), ('조선', 398), ('의혹', 385), ('조사', 376), ('배치', 373), ('공개', 371), ('시장', 363), ('트럼프', 355), ('지원', 351), ('북한', 348), ('시간', 346), ('우리', 337), ('요금', 335), ('전기', 333), ('반대', 328), ('경제', 327), ('성주', 324), ('이정현', 322), ('구속', 320), ('영상', 318), ('이유', 317), ('특별', 316), ('사고', 314), ('추진', 309), ('학교', 307), ('미국', 305), ('사람', 305)]
# 09 [('지진', 1289), ('대통령', 850), ('한국', 760), ('정부', 580), ('규모', 548), ('추석', 535), ('서울', 511), ('중국', 473), ('경주', 471), ('세계', 462), ('사망', 446), ('사드', 443), ('가능', 429), ('북한', 413), ('기업', 410), ('경찰', 399), ('지원', 395), ('여성', 392), ('논란', 375), ('의혹', 375), ('한진', 374), ('안전', 371), ('김영란', 368), ('국회', 349), ('핵실험', 345), ('검찰', 340), ('시장', 339), ('해운', 334), ('대표', 333), ('피해', 324), ('공개', 322), ('미국', 319), ('부산', 313), ('일본', 311), ('최대', 306), ('국민', 294), ('의원', 293), ('검사', 291), ('경제', 287), ('시간', 279), ('영상', 277), ('대선', 277), ('정상', 277), ('백남기', 276), ('이정현', 275), ('트럼프', 271), ('갤노트', 267), ('조사', 267), ('파업', 266), ('국감', 264)]
# 10 [('최순실', 2483), ('대통령', 1845), ('한국', 835), ('의혹', 807), ('논란', 669), ('검찰', 629), ('경찰', 588), ('중국', 542), ('정부', 542), ('서울', 524), ('수사', 521), ('박근혜', 501), ('사망', 476), ('트럼프', 452), ('기업', 424), ('세계', 418), ('백남기', 416), ('시장', 400), ('여성', 383), ('태풍', 372), ('경제', 371), ('국민', 368), ('조사', 367), ('청와대', 364), ('교수', 364), ('미르', 353), ('중단', 348), ('가능', 344), ('시간', 340), ('사람', 331), ('미국', 329), ('개헌', 328), ('재단', 328), ('영상', 323), ('문재인', 322), ('부산', 320), ('삼성', 312), ('갤노트', 311), ('국감', 306), ('공개', 306), ('대선', 303), ('의원', 303), ('북한', 293), ('시민', 286), ('이유', 285), ('일본', 285), ('사고', 284), ('지원', 276), ('우리', 273), ('피해', 273)]
# 11 [('대통령', 5554), ('최순실', 2886), ('트럼프', 1910), ('박근혜', 1877), ('탄핵', 1356), ('검찰', 1262), ('퇴진', 1185), ('촛불', 1035), ('청와대', 976), ('수사', 951), ('조사', 873), ('의혹', 856), ('한국', 831), ('국정', 701), ('총리', 682), ('국민', 649), ('집회', 645), ('촛불집회', 643), ('대선', 591), ('시민', 579), ('시간', 560), ('논란', 556), ('정보', 536), ('서울', 494), ('정부', 468), ('게이트', 467), ('가능', 461), ('경찰', 460), ('특검', 454), ('교과서', 453), ('협정', 445), ('군사', 440), ('국회', 426), ('시장', 421), ('기업', 419), ('정유라', 419), ('우병우', 414), ('요구', 414), ('미국', 409), ('내년', 403), ('삼성', 401), ('중국', 392), ('의원', 387), ('세월호', 382), ('경제', 374), ('정치', 366), ('공개', 366), ('추진', 364), ('차은택', 361), ('세계', 358)]
# 12 [('탄핵', 2183), ('대통령', 1776), ('최순실', 854), ('박근혜', 603), ('촛불', 551), ('퇴진', 491), ('국회', 443), ('세월호', 401), ('청와대', 397), ('한국', 378), ('의원', 372), ('특검', 364), ('청문회', 358), ('트럼프', 355), ('수사', 343), ('국민', 339), ('표결', 315), ('시간', 314), ('가결', 303), ('내년', 272), ('시민', 263), ('국정', 260), ('김기춘', 245), ('촛불집회', 241), ('논란', 237), ('정치', 235), ('경제', 235), ('새누리', 231), ('헌재', 222), ('정부', 218), ('새누리당', 211), ('중국', 211), ('서울', 208), ('가능', 206), ('대선', 204), ('의혹', 196), ('비박', 192), ('집회', 191), ('기업', 190), ('사퇴', 190), ('시장', 189), ('이재명', 187), ('삼성', 185), ('공개', 180), ('교과서', 176), ('경찰', 174), ('세계', 173), ('우병우', 170), ('이재용', 165), ('영상', 159)]

# %%
df_by_month.agg(['mean', 'count'])
# Out:
#         org_count        naver_count        total_count
#              mean  count        mean  count        mean  count
# month
# 01     165.487125  40466   23.049745  40466  188.536870  40466
# 02     168.984964  37111   25.549163  37111  194.534127  37111
# 03     126.101200  40761   22.099114  40761  148.200314  40761
# 04     151.722805  37378   25.495265  37378  177.218069  37378
# 05     133.163774  39695   24.974405  39695  158.138179  39695
# 06     121.357529  41303   22.615137  41303  143.972665  41303
# 07     143.167743  43680   25.951809  43680  169.119551  43680
# 08     177.883799  41213   29.496809  41213  207.380608  41213
# 09     205.389246  33326   31.558393  33326  236.947638  33326
# 10     279.059524  36439   35.309449  36439  314.368973  36439
# 11     356.246586  40574   44.942648  40574  401.189234  40574
# 12     328.621973  18086   36.790335  18086  365.412308  18086

# %%
df.reset_index().to_json('data/mecab.json',orient='records')

# %%
# %%time
from collections import Counter

## df 방식과 counter 방식의 현저한 속도차
#result = df['title_noun'].head(20000).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0)
#result.sort_values(axis=0, ascending=False)
r1 = df['title_me_noun'].tolist()
result = Counter(" ".join(r1).split(" "))
# Out:
# CPU times: user 1.08 s, sys: 56 ms, total: 1.14 s
# Wall time: 1.14 s

# %%
result.most_common(100)
# Out:
# [('대통령', 17007),
#  ('한국', 10930),
#  ('정부', 7033),
#  ('서울', 6961),
#  ('중국', 6614),
#  ('최순실', 6340),
#  ('논란', 6324),
#  ('기업', 5648),
#  ('트럼프', 5563),
#  ('세계', 5521),
#  ('시장', 5367),
#  ('경찰', 5303),
#  ('검찰', 5151),
#  ('여성', 5077),
#  ('사드', 5020),
#  ('경제', 4906),
#  ('가능', 4765),
#  ('수사', 4721),
#  ('의혹', 4682),
#  ('의원', 4578),
#  ('사망', 4535),
#  ('더민주', 4492),
#  ('대표', 4489),
#  ('조사', 4472),
#  ('시간', 4271),
#  ('국회', 4265),
#  ('박근혜', 4255),
#  ('공개', 4200),
#  ('북한', 4167),
#  ('국민', 4041),
#  ('미국', 4002),
#  ('일본', 3931),
#  ('탄핵', 3867),
#  ('우리', 3750),
#  ('정치', 3732),
#  ('지원', 3705),
#  ('조선', 3663),
#  ('영상', 3522),
#  ('이유', 3481),
#  ('최고', 3452),
#  ('최대', 3430),
#  ('부산', 3367),
#  ('사람', 3306),
#  ('새누리', 3262),
#  ('추진', 3195),
#  ('국민의당', 3092),
#  ('총선', 3079),
#  ('후보', 3038),
#  ('시민', 3037),
#  ('전국', 3015),
#  ('사고', 2998),
#  ('개발', 2973),
#  ('청와대', 2937),
#  ('구속', 2901),
#  ('투자', 2894),
#  ('지진', 2881),
#  ('세월호', 2855),
#  ('사업', 2801),
#  ('삼성', 2791),
#  ('청년', 2751),
#  ('최신', 2742),
#  ('국내', 2734),
#  ('대선', 2729),
#  ('문제', 2715),
#  ('규모', 2706),
#  ('시대', 2688),
#  ('학교', 2662),
#  ('정보', 2654),
#  ('연합뉴스', 2649),
#  ('테러', 2637),
#  ('교육', 2626),
#  ('공항', 2613),
#  ('이상', 2610),
#  ('배치', 2598),
#  ('피해', 2590),
#  ('사회', 2570),
#  ('안철수', 2565),
#  ('김종인', 2524),
#  ('안전', 2509),
#  ('회장', 2508),
#  ('제주', 2483),
#  ('', 2480),
#  ('시작', 2478),
#  ('위기', 2470),
#  ('반대', 2453),
#  ('교수', 2452),
#  ('구조', 2439),
#  ('지역', 2435),
#  ('발견', 2434),
#  ('문화', 2433),
#  ('중단', 2427),
#  ('오늘', 2404),
#  ('금융', 2395),
#  ('국가', 2386),
#  ('사건', 2339),
#  ('혐의', 2296),
#  ('아이', 2263),
#  ('아파트', 2257),
#  ('학생', 2250),
#  ('위안부', 2243)]

# %%
# %%time
from konlpy.tag import Twitter
twitter = Twitter()
def words(sentence):
    word_list = twitter.nouns(sentence)
    return " ".join(word_list)

df['title_noun'] = df['title'].apply(words)
#df.reset_index().to_json('data/twitter.json',orient='records')
# Out:
# CPU times: user 3min 58s, sys: 592 ms, total: 3min 59s
# Wall time: 3min 54s
