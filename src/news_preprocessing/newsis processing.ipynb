# %%
import glob

files = glob.glob('./data/2014/*/newsisall.json')

# %%
import json
def read_json_file(path_to_file):
    with open(path_to_file) as p:
        rows=[json.loads(line) for line in p]
    return rows

# %%
import pandas as pd

data=[]
for path in files:
    data.extend(read_json_file(path))

df = pd.DataFrame(data)

# %%
df=df.dropna(subset=['section'])
df=df.reset_index(drop=True)

# %%
df.drop(['naver_url','org_url'], axis = 1, inplace = True)

# %%
article=df['article'][9].replace('▶','\n▶').replace('\t', '').replace('\n', ' ')#.split('\n')
article
# Out:
# '         【서울=뉴시스】조종원 기자 = 제95주년 삼일절인 1일 서울 강북구 우이동 도선사에서 열린 제11회 봉황각 3.1 독립운동 재현행사 타종식에 참석한 시민들이 민족대표 33인을 기리는 33번의 추모 타종행사를 실시하고 있다. 2014.03.01. (사진=강북구 제공)   photo@newsis.com  [사진 영상 제보받습니다] 공감언론 뉴시스가 독자 여러분의 소중한 제보를 기다립니다. 뉴스 가치나 화제성이 있다고 판단되는 사진 또는 영상을 뉴시스 사진영상부(n-photo@newsis.com, 02-721-7470)로 보내주시면 적극 반영하겠습니다.  ★ 뉴시스 뉴스, 이젠 네이버 뉴스 스탠드에서도 만나세요  ★ 손 안에서 보는 세상, 모바일 뉴시스      '

# %%
import re

#article = re.sub(r'[a-zA-Z0-9]+@newsis.com(.*)', '', article)
article = re.sub(r'20[0-9]+.[0-9]+.[0-9]+.(.*)', '', article)

article
# Out:
# '         【서울=뉴시스】조종원 기자 = 제95주년 삼일절인 1일 서울 강북구 우이동 도선사에서 열린 제11회 봉황각 3.1 독립운동 재현행사 타종식에 참석한 시민들이 민족대표 33인을 기리는 33번의 추모 타종행사를 실시하고 있다. '

# %%
import re
def remove_extras(article):
    return_article = ''
    article = re.sub(r'\/\/[a-zA-Z가-힣 \n]+|{}|_flash_removeCallback\(\)', '', article)
    article = article.replace('▶','\n▶').replace('\t', '').replace('\n', ' ')
    #remove by line
    article = re.sub(r'\【[a-zA-Z가-힣· ]+\=[a-zA-Z가-힣/ ]+\】[a-zA-Z가-힣· ]+ =|\【[a-zA-Z가-힣· ]+\=[a-zA-Z가-힣/ ]+\】|\<< [a-zA-Z가-힣· ]+\=[a-zA-Z가-힣· ]+ >>|\([a-zA-Z가-힣0-9·, ]+\=[a-zA-Z가-힣· ]+\)|\[[a-zA-Z가-힣·= ]+[자료사진 ]\]|\(연합뉴스 DB\)|\[[a-zA-Z가-힣 ]+제공\]|\[[a-zA-Z가-힣 ]+제공=연합뉴스\]', '', article)
    #remove copyrithgs
    #article = article.replace('<저작권자(c) 연합뉴스, 무단 전재-재배포 금지>', '')
    #remove email
    #article = re.sub(r'[a-zA-Z0-9_-]+@[a-z]+.[a-z]+.[a-z]+', '', article)
    #remove tail
    
    #for sentence in article.split('\n'):
    #    if not sentence.startswith('▶') : return_article += sentence

    #return_article = return_article.replace('\n', ' ')
    article = re.sub(r'20[0-9 ]+.[0-9 ]+.[0-9 ]+(.*)', '', article)
    article = re.sub(r'([a-z.]+@newsis.com)(.*)', '', article)

    return article

# %%
df['article'][317826]
# Out:
# '\n\n\n\n\n\n\n\n\n【서울=뉴시스】유상우 기자 = “우리 주교들과 사제들은 가톨릭 가정을 포함한 (저출산을 해결할) 모든 이해 당사자들을 도와야 한다.”\n\n 세계주교대의원회의 제3차 임시총회에 참석 중인 천주교 서울대교구장 염수정 추기경은 지난 9일(현지시각) 바오로 6세 홀에서 ‘저출산과 교회의 가정 사목’에 대한 발표를 통해 이렇게 말했다.\n\n 염 추기경은 “의안집 130항과 131항에 나와 있는 ‘생명에 대한 개방성의 의식을 고양시킴’에 관해 언급하고 싶다”면서 “혼인한 부부들의 생각을 생명에 열려 있게 하기 위해서는 부모와 이해 관계자들의 가치관 전체의 변화가 필요하다”고 짚었다.\n\n 이어 “특별히 매스미디어와 법률 입안에 관련된 이들, 그리고 출산에 우호적인 법안과 정책을 만드는 데 책임이 있는 공공 기관에 종사하는 이들을 양성해야 한다”며 더 실질적이고 적극적인 변화를 이끌어 내는 데 교회가 노력해야 함을 강조했다.\n\n 염 추기경은 10년 넘게 교구 생명위원회와 매스컴위원회 위원장으로 일한 바 있다.\n\n 염 추기경은 생업으로 가족을 돌보는 데 어려움을 겪는 아시아의 상황을 비춰 보며 “교구와 본당은 맞벌이 부부들이 생업과 가정을 더욱 잘 조화시킬 수 있도록 아이와 노인을 돌보는 일을 할 수 있다”고 구체적 역할을 제시했다.\n\n 그는 “우리 주교들과 형제 사제들 역시 혼인과 가정에 관한 교도권의 가르침에 대한 충분한 지식이 필요하다”며 “주교들과 사제들은 극도로 세속화된 사회의 중심에서 반대의 표징이 되는 것을 절대로 두려워하면 안 된다”고 했다. “자연윤리와 복음 윤리 전체를 겸손하지만 확고하게 전파하며 부부 사랑과 생명 전달의 부서지지 않는 다리가 돼야 한다.”\n\n 또 “안타깝게도 경제가 발전함과 반대로 더 적은 아이들이 태어나는 것이 전 세계적 현상이 됐다”면서 “출산율의 저하는 우리 문명의 생존을 위협한다. 인간의 운명은 위기에 처해 있는 것이 현실”이라고도 진단했다. \n\n 이 자리에는 200여 명의 주교들이 참석했다.\n\n 한편, 프란치스코 교황이 지난 7일 추기경회의를 별도로 추가함에 따라 염 추기경은 19일 주교회의를 마친 후 귀국하지 않고 곧바로 20일 하루 열리는 추기경회의에 참석한다.\n\n 교황청 대변인 페데리코 롬바르디 신부는 지난 7일 브리핑을 통해 “추기경회의의 주제가 넓어지면서 모든 추기경과 주교들은 중동 기독교인들의 상황에 대해 교황 대사들의 회의 내용을 바탕으로 토론하게 될 것”이라고 밝혔다.\n\n 중동의 교황 대사들과 UN 교황대사 실바노 토마시 대주교, 교황청 꾸리아 장관들은 지난 2일부터 4일까지 중동 문제에 관해 회의를 진행한 후 “중동문제의 해결이 군사적 대응에 전적으로 위임될 수 없다”며 “우리가 점점 익숙해지는 폭력사태들을 막아야 한다”고 촉구하는 보고서를 발표했다.\n\n 염 추기경은 모든 일정을 마치고 22일 한국행 비행길에 오른다.\n\n swryu@newsis.com\n\n★ 뉴시스 뉴스, 이젠 네이버 뉴스 스탠드에서도 만나세요\n\n★ 손 안에서 보는 세상, 모바일 뉴시스\n\n\n\n\n\n'

# %%
print(remove_extras(df['article'][317826]))
# Out:
#           “우리 주교들과 사제들은 가톨릭 가정을 포함한 (저출산을 해결할) 모든 이해 당사자들을 도와야 한다.”   세계주교대의원회의 제3차 임시총회에 참석 중인 천주교 서울대교구장 염수정 추기경은 지난 9일(현지시각) 바오로 6세 홀에서 ‘저출산과 교회의 가정 사목’에 대한 발표를 통해 이렇게 말했다.   염 추기경은 “의안집 130항과 131항에 나와 있는 ‘생명에 대한 개방성의 의식을 고양시킴’에 관해 언급하고 싶다”면서 “혼인한 부부들의 생각을 생명에 열려 있게 하기 위해서는 부모와 이해 관계자들의 가치관 전체의 변화가 필요하다”고 짚었다.   이어 “특별히 매스미디어와 법률 입안에 관련된 이들, 그리고 출산에 우호적인 법안과 정책을 만드는 데 책임이 있는 공공 기관에 종사하는 이들을 양성해야 한다”며 더 실질적이고 적극적인 변화를 이끌어 내는 데 교회가 노력해야 함을 강조했다.   염 추기경은 10년 넘게 교구 생명위원회와 매스컴위원회 위원장으로 일한 바 있다.   염 추기경은 생업으로 가족을 돌보는 데 어려움을 겪는 아시아의 상황을 비춰 보며 “교구와 본당은 맞벌이 부부들이 생업과 가정을 더욱 잘 조화시킬 수 있도록 아이와 노인을 돌보는 일을 할 수 있다”고 구체적 역할을 제시했다.   그는 “우리 주교들과 형제 사제들 역시 혼인과 가정에 관한 교도권의 가르침에 대한 충분한 지식이 필요하다”며 “주교들과 사제들은 극도로 세속화된 사회의 중심에서 반대의 표징이 되는 것을 절대로 두려워하면 안 된다”고 했다. “자연윤리와 복음 윤리 전체를 겸손하지만 확고하게 전파하며 부부 사랑과 생명 전달의 부서지지 않는 다리가 돼야 한다.”   또 “안타깝게도 경제가 발전함과 반대로 더 적은 아이들이 태어나는 것이 전 세계적 현상이 됐다”면서 “출산율의 저하는 우리 문명의 생존을 위협한다. 인간의 운명은 위기에 처해 있는 것이 현실”이라고도 진단했다.    이 자리에는 200여 명의 주교들이 참석했다.   한편, 프란치스코 교황이 지난 7일 추기경회의를 별도로 추가함에 따라 염 추기경은 19일 주교회의를 마친 후 귀국하지 않고 곧바로 20일 하루 열리는 추기경회의에 참석한다.   교황청 대변인 페데리코 롬바르디 신부는 지난 7일 브리핑을 통해 “추기경회의의 주제가 넓어지면서 모든 추기경과 주교들은 중동 기독교인들의 상황에 대해 교황 대사들의 회의 내용을 바탕으로 토론하게 될 것”이라고 밝혔다.   중동의 교황 대사들과 UN 교황대사 실바노 토마시 대주교, 교황청 꾸리아 장관들은 지난 2일부터 4일까지 중동 문제에 관해 회의를 진행한 후 “중동문제의 해결이 군사적 대응에 전적으로 위임될 수 없다”며 “우리가 점점 익숙해지는 폭력사태들을 막아야 한다”고 촉구하는 보고서를 발표했다.   염 추기경은 모든 일정을 마치고 22일 한국행 비행길에 오른다.

# 672887              정의화 국회의장이 예산안 법정 처리 시한(2일)을 하루 앞둔 1일...
# Name: article, Length: 672888, dtype: object

# %%
counts=df.groupby('section').size()
sorted_counts=counts.sort_values(ascending=False)

# %%
sorted_counts
# Out:
# section
# 사회|사회일반        155140
# 정치|정치일반         65072
# 경제|경제일반         45058
# 전국|강원           23019
# 스포츠|스포츠일반       21357
# 스포츠|야구/MLB      19867
# 전국|대구/경북        19291
# 전국|대전/충남        16329
# 스포츠|축구          14989
# 연예|연예일반         14712
# 사회|사건/사고        14542
# 국제|미주           13875
# 전국|충북           13855
# 정치|행정           12577
# 국제|유럽           12207
# 경제|산업/기업        12071
# 전국|전북           10403
# 정치|국방/외교/북한      9454
# 전국|경기남부          9113
# 스포츠|농구           8994
# 전국|광주/전남         8944
# 국제|아시아/대양주       8921
# 사회|교육/취업/노동      8279
# 전국|울산            8277
# 전국|부산            8130
# 전국|제주            7950
# 전국|서울            7611
# 정치|청와대           7356
# 전국|경남            6880
# 사회|법원/검찰         6701
#                 ...
# 경제|농수축산           380
# 사회|수능             378
# 국제|국제기구           274
# 문화|문학             239
# 문화|생활             234
# 경제|CEO            210
# 기타|그래픽            207
# 연예|미디어            174
# 문화|문화계            123
# 경제|창업/취업          119
# 경제|증권             118
# 사람들|동정             87
# 연예|만화              51
# 라이프|생활             50
# 오피니언|기자수첩          47
# 오피니언|크로스로드         38
# 라이프|여행레저           31
# 연예|해외연예            29
# 오피니언|기고            22
# 경제|단신              16
# 사람들|인터뷰            16
# 경제|기업 실적           14
# 경제|국제경제            10
# 오피니언|데스크창          10
# 사람들|이 사람            4
# 오피니언|포럼·세미나         3
# 경제|종목토크             1
# 라이프|패션/뷰티           1
# 산업|유통/생활경제          1
# 사람들|본사손님            1
# Length: 88, dtype: int64

# %%
df.to_pickle('newsis_2014.pkl')

# %% [markdown]
# ### Compare Memory Usage
#
# ```
# df['article']=pd.Series([val for val in df['article'].str.replace(r'\r|\t|\n|\/\/[a-zA-Z가-힣 \n]+|{}|_flash_removeCallback\(\)|[a-zA-Z0-9]+@yonhapnews.co.kr|\[연합뉴스[a-zA-Z가-힣 ]+\]|\([a-zA-Z가-힣· ]+\=연합뉴스\)|\[[a-zA-Z가-힣 ]+\=연합뉴스\]|[a-zA-Z가-힣 ]+ 기자 \=|[a-zA-Z가-힣 ]+ 특파원 \=','')])
# ```
#
# ```
# df['article']=df['article'].str.replace(r'\[연합뉴스[a-zA-Z가-힣 ]+\]|\([a-zA-Z가-힣· ]+\=연합뉴스\)|\[[a-zA-Z가-힣 ]+\=연합뉴스\]|[a-zA-Z가-힣 ]+ 기자 \=|[a-zA-Z가-힣 ]+ 특파원 \=','')
# ```

# %%
df.memory_usage(deep=True)
# Out:
# Index         2360328
# article    1181572465
# author       28497751
# date         19767747
# section      29771250
# title        59625664
# sec_idx       2360328
# dtype: int64
