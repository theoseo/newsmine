# %%
import glob

files = glob.glob('./data/2017/*/jtbc/*.json')

# %%
import json
def read_json_file(path_to_file):
    with open(path_to_file) as p:
        rows=[json.loads(line) for line in p]
    return rows

# %%
import pandas as pd

data=[]
for path in files:
    data.extend(read_json_file(path))

df = pd.DataFrame(data)

# %%
df.drop(['comments','image','naver_section','naver_url','org_url','time','vod'], axis = 1, inplace = True)

# %%
import pandas as pd

with open('./data/jtbc_2016.pkl', 'rb') as f1:
    df2016 = pd.read_pickle(f1)

# %%
df2016.rename(columns={'content': 'article'}, inplace=True)

# %%
df2016.drop(['oid','aid','media','naver_count','org_count','org_url','total_count','ml_section'], axis = 1, inplace = True)

# %%
df=df[['date', 'title', 'article', 'section']]

# %%
df=df.append(df2016)
df=df.reset_index(drop=True)

# %%
article=df['article'][24000].replace('▶','\n▶').replace('\t', '').replace('\n', ' ')#.split('\n')
article
# Out:
# '[앵커]지금 보신 것처럼 새누리당은 벌써 총선 이후 당내 주도권 싸움이 벌어진 모습인데요. 정치부 이성대 기자와 좀 더 얘기해보겠습니다. 이 기자, 오늘(27일) 원유철 원내대표가 탈당한 무소속 의원들이 당선이 된다해도 복당은 안된다 이렇게 얘길하지 않았습니까. 보통 총선 전에는 한 석이 아쉬워서 우는 소리한다고까지 하는데 이렇게 이야기한 이유는 뭘로 봐야 할까요?[기자]일단은 대구를 겨냥했다는 분석이 나오는데요, 우선 대구 일각에서 부는 친유승민계 바람을 미리 차단하려고 했던 게 아니냐는 분석입니다.\'찍어줘봐야 어차피 복당을 안시켜줄테니\' 아예 \'투표할 때부터 찍어주지마라\'라는 메세지를 대구 시민들에게 보낸 게 아니냐는 거죠.실제로 친박계 조원진 의원 같은 경우에 오늘 대구시당에서 후보자들 회의를 열면서 "복당 불허는 당론이다"라며 다시 한번 강조하기도 했습니다.[앵커]대구에서 혹시나 비박계 바람이 불면서 일 수 있는 것들을 미리 차단한다고 볼 수 있겠군요. 오늘 보면 "당헌·당규상 복당은 낙타가 바늘구멍 들어가는 것처럼 어렵다"고 했는데 정말로 복당 절차가 어려운 겁니까?[기자]새누리당 당헌·당규를 살펴봐야되는데요. 당원 자격을 규정한 당규 5조 2항에 따르면 \'탈당 후 다른 정당 후보 또는 무소속 후보로 국회의원 선거에 출마한 경우 등 해당행위의 정도가 심한 자는 시도당은 최고위원회의의 승인을 얻어 입당을 허가할 수 있다\'고 쓰여 있습니다.즉, 유승민 의원이 당선돼서 복당을 하고싶어도 최고위 의결 거쳐야하는데 현재 친박계가 다수를 점하고 있는 최고위의 인적 구성상 절대로 복당 허락을 안해주겠다는 의지를 내비친 겁니다.[앵커]요즘 들어서 새누리당 당헌·당규를 자주 보게 되는데 이렇게까지 언급하는 건 결국 무소속 의원들의 당선 가능성이 크기 때문이라고 바꿔 생각할 수도 있지 않을까요?[기자]당장 유승민 의원의 경우만 보아도 유 의원의 지역구인 대구 동구을에 대해서 새누리당은 무공천 결정을 내렸습니다.그래서 진박계 유력후보였던 이재만 전 동구청장의 출마가 불발되면서, 사실상 유승민 의원의 당선 가능성이 더 커진 상태입니다. 그러니 친박계가 유승민 의원의 공천 배제를 시도했지만, 결과적으로 오히려 유 의원의 당선 가능성을 높여줬다는 해석이 나오고 있는 상황입니다.[앵커]오늘 친박계 지도부가 꺼낸 얘기가 결국은 \'총선 이후의 유 의원 견제카드다\' 이렇게 볼 수 있겠군요.[기자]그렇습니다. 일단 당내 상황을 보면 총선 이후 7월에 전당대회가 가능성이 있습니다. 여기서 친박계는 당권을 잡기 위해 총력전을 펼칠 가능성이 큽니다. 그런데 유승민 의원이 복당하게되면 스스로 당권주자가 되거나, 비박계 주자를 도울 가능성이 큽니다. 게다가 유승민 의원의 바람을 타고 다른 무소속 후보들까지 당선해 들어오게 되면, 당 내 유승민 의원의 포지션이 더 커질 수 밖에 없는 것이고 이를 결코 달가워하지 않을 친박계에선 복당을 해주지 않을 것이라는 전망이 우세한 거죠.[앵커]그런데 만약 친박계 의원들이 이렇게 했음에도 불구하고, 결국 무소속 후보들이 다수가 당선된다면 상황이 달라지지 않을까요?[기자]일단 총선 결과에 따라 추후에 구도가 달라질 수 있다는 분석이 나오는데요, 예를들어 새누리당이 과반에 몇석 못미치는, 145~7석이라면 유 의원에 대한 복당 여론이 커질 것이라는 전망이 있습니다. 게다가 5월 초 열리는 원내대표 경선에서 비박계 후보가 당선되면, 유승민 복당 여론이 클 것이라는 전망이 나옵니다.하지만 새누리당이 자체 과반을 확보하게 되면, 공천 파동에도 불구하고 선방을 했다거나 또는 승리했다는 분석이 나올 수밖에 없어서 유승민 의원의 복당 문제는 뒤로 밀릴 가능성이 큽니다.[앵커]지난주에 정의화 국회의장이 이렇게 이야기했죠. "공천이 아니라 악랄한 사천"이란 표현을 쓰지 않았습니까. 그러면서 "유승민 의원도 복당하지 않길 바란다"고 말했습니다. 이게 무슨 의미입니까?[기자]그렇습니다. 지난주 목요일 기자들을 만나 "본인도 복당을 하지 않겠다"고 얘기했습니다.국회의장은 보통 무소속으로 임무를 마치고, 친정으로 돌아가는 게 일반적인데 돌아가지 않겠다고 얘기한 겁니다. 그만큼 친박 주도의 공천 파동에 대해서 반감이 크다는 비판을 했다고 볼 수 있습니다. 다만 유 의원에게도 "복당을 안했으면 좋겠다"고 얘기했던 건, 정의화 의장이 향후 대선을 앞두고 독자 세력에 관심이 있다는 얘기를 했기 때문에 그 과정에서 유 의원과 연대 손짓을 보낸 게 아니냐는 분석도 나오고 있습니다.[앵커]지금도 대구에서 비박 연대, 무소속 연대가 나오는데 총선 이후에 그 얘기가 분명히 이슈로 떠오르겠군요. 정치부 이성대 기자였습니다.이성대 ▶ JTBC 뉴스 공식 SNS [트위터] [페이스북] [카카오스토리] [유튜브] ▶ JTBC 뉴스는 여러분의 생생한 제보를 기다립니다.  Copyright by JTBC, DramaHouse & JcontentHub Co., Ltd. All Rights Reserved. 무단 전재 및 재배포 금지'

# %%
import re
article = re.sub(r'\/\/[a-zA-Z가-힣 \n]+|{}|_flash_removeCallback\(\)', '', article)
#article = re.sub(r'\[중앙[a-zA-Z가-힣 ]+\]', '', article)
#article = re.sub(r'\[사진 [a-zA-Z가-힣]+\]', '', article)
article = re.sub(r'\[(앵커|기자)\]', '', article)
article = re.sub(r'[0-9가-힣=()· ]+\([a-z0-9.]+@jtbc.co.kr\)(.*)', '', article)
article = re.sub(r'[0-9가-힣=() ]+▶(.*)', '', article)
article = re.sub(r'▶ JTBC 뉴스 공식(.*)', '', article)
#article = re.sub(r'\[ⓒ 조인스랜드 (.*)\]', '', article)

article
# Out:
# '지금 보신 것처럼 새누리당은 벌써 총선 이후 당내 주도권 싸움이 벌어진 모습인데요. 정치부 이성대 기자와 좀 더 얘기해보겠습니다. 이 기자, 오늘(27일) 원유철 원내대표가 탈당한 무소속 의원들이 당선이 된다해도 복당은 안된다 이렇게 얘길하지 않았습니까. 보통 총선 전에는 한 석이 아쉬워서 우는 소리한다고까지 하는데 이렇게 이야기한 이유는 뭘로 봐야 할까요?일단은 대구를 겨냥했다는 분석이 나오는데요, 우선 대구 일각에서 부는 친유승민계 바람을 미리 차단하려고 했던 게 아니냐는 분석입니다.\'찍어줘봐야 어차피 복당을 안시켜줄테니\' 아예 \'투표할 때부터 찍어주지마라\'라는 메세지를 대구 시민들에게 보낸 게 아니냐는 거죠.실제로 친박계 조원진 의원 같은 경우에 오늘 대구시당에서 후보자들 회의를 열면서 "복당 불허는 당론이다"라며 다시 한번 강조하기도 했습니다.대구에서 혹시나 비박계 바람이 불면서 일 수 있는 것들을 미리 차단한다고 볼 수 있겠군요. 오늘 보면 "당헌·당규상 복당은 낙타가 바늘구멍 들어가는 것처럼 어렵다"고 했는데 정말로 복당 절차가 어려운 겁니까?새누리당 당헌·당규를 살펴봐야되는데요. 당원 자격을 규정한 당규 5조 2항에 따르면 \'탈당 후 다른 정당 후보 또는 무소속 후보로 국회의원 선거에 출마한 경우 등 해당행위의 정도가 심한 자는 시도당은 최고위원회의의 승인을 얻어 입당을 허가할 수 있다\'고 쓰여 있습니다.즉, 유승민 의원이 당선돼서 복당을 하고싶어도 최고위 의결 거쳐야하는데 현재 친박계가 다수를 점하고 있는 최고위의 인적 구성상 절대로 복당 허락을 안해주겠다는 의지를 내비친 겁니다.요즘 들어서 새누리당 당헌·당규를 자주 보게 되는데 이렇게까지 언급하는 건 결국 무소속 의원들의 당선 가능성이 크기 때문이라고 바꿔 생각할 수도 있지 않을까요?당장 유승민 의원의 경우만 보아도 유 의원의 지역구인 대구 동구을에 대해서 새누리당은 무공천 결정을 내렸습니다.그래서 진박계 유력후보였던 이재만 전 동구청장의 출마가 불발되면서, 사실상 유승민 의원의 당선 가능성이 더 커진 상태입니다. 그러니 친박계가 유승민 의원의 공천 배제를 시도했지만, 결과적으로 오히려 유 의원의 당선 가능성을 높여줬다는 해석이 나오고 있는 상황입니다.오늘 친박계 지도부가 꺼낸 얘기가 결국은 \'총선 이후의 유 의원 견제카드다\' 이렇게 볼 수 있겠군요.그렇습니다. 일단 당내 상황을 보면 총선 이후 7월에 전당대회가 가능성이 있습니다. 여기서 친박계는 당권을 잡기 위해 총력전을 펼칠 가능성이 큽니다. 그런데 유승민 의원이 복당하게되면 스스로 당권주자가 되거나, 비박계 주자를 도울 가능성이 큽니다. 게다가 유승민 의원의 바람을 타고 다른 무소속 후보들까지 당선해 들어오게 되면, 당 내 유승민 의원의 포지션이 더 커질 수 밖에 없는 것이고 이를 결코 달가워하지 않을 친박계에선 복당을 해주지 않을 것이라는 전망이 우세한 거죠.그런데 만약 친박계 의원들이 이렇게 했음에도 불구하고, 결국 무소속 후보들이 다수가 당선된다면 상황이 달라지지 않을까요?일단 총선 결과에 따라 추후에 구도가 달라질 수 있다는 분석이 나오는데요, 예를들어 새누리당이 과반에 몇석 못미치는, 145~7석이라면 유 의원에 대한 복당 여론이 커질 것이라는 전망이 있습니다. 게다가 5월 초 열리는 원내대표 경선에서 비박계 후보가 당선되면, 유승민 복당 여론이 클 것이라는 전망이 나옵니다.하지만 새누리당이 자체 과반을 확보하게 되면, 공천 파동에도 불구하고 선방을 했다거나 또는 승리했다는 분석이 나올 수밖에 없어서 유승민 의원의 복당 문제는 뒤로 밀릴 가능성이 큽니다.지난주에 정의화 국회의장이 이렇게 이야기했죠. "공천이 아니라 악랄한 사천"이란 표현을 쓰지 않았습니까. 그러면서 "유승민 의원도 복당하지 않길 바란다"고 말했습니다. 이게 무슨 의미입니까?그렇습니다. 지난주 목요일 기자들을 만나 "본인도 복당을 하지 않겠다"고 얘기했습니다.국회의장은 보통 무소속으로 임무를 마치고, 친정으로 돌아가는 게 일반적인데 돌아가지 않겠다고 얘기한 겁니다. 그만큼 친박 주도의 공천 파동에 대해서 반감이 크다는 비판을 했다고 볼 수 있습니다. 다만 유 의원에게도 "복당을 안했으면 좋겠다"고 얘기했던 건, 정의화 의장이 향후 대선을 앞두고 독자 세력에 관심이 있다는 얘기를 했기 때문에 그 과정에서 유 의원과 연대 손짓을 보낸 게 아니냐는 분석도 나오고 있습니다.지금도 대구에서 비박 연대, 무소속 연대가 나오는데 총선 이후에 그 얘기가 분명히 이슈로 떠오르겠군요. 정치부 이성대 기자였습니다.'

# %%
import re
def remove_jtbc_extras(article):   
    article = article.replace('▶','\n▶').replace('\t', '').replace('\n', ' ')#.split('\n')
    article = re.sub(r'\/\/[a-zA-Z가-힣 \n]+|{}|_flash_removeCallback\(\)', '', article)
    article = re.sub(r'\[(앵커|기자)\]', '', article)
    article = re.sub(r'[0-9가-힣=()· ]+\([a-z0-9.]+@jtbc.co.kr\)(.*)', '', article)
    article = re.sub(r'[0-9가-힣=() ]+▶(.*)', '', article)
    article = re.sub(r'▶ JTBC 뉴스 공식(.*)', '', article)

    article = article.replace('\n', ' ')
    return article

# %%
print(remove_jtbc_extras(df['article'][29]))
# Out:
#       중진공 '채용 외압' 의혹 최경환 의원 불구속 기소  (JTBC 뉴스운영팀)

# %%
df['article']=df['article'].apply(lambda x: remove_jtbc_extras(x))
df['article']
# Out:
# 0                   대선이 오늘(20일)로 꼭 50일 남았습니다. 박근혜 대통령 파...
# 1                   그렇다면 박근혜 전 대통령은 어떤 카드를 들고 나올까. 여기에도...
# 2                   트럼프 정부가 연일 북한에 대한 선제타격 옵션까지 거론하며 대북...
# 3                 중소기업진흥공단에 직원을 채용해 달라고 압력을 행사한 의혹을 받고 ...
# 4                   대선 주자들은 어디 가서 어떤 메시지를 낼까를 매일 고민한다고 ...
# 5                   문재인 대세론의 변수 중 하나로 지목되는 것이 바로 보수층의 결...
# 6                   북한이 새로운 로켓 엔진 기술을 공개하면서 고강도 도발 가능성을...
# 7                   횡령 등의 혐의로 재판에 넘겨진 롯데그룹 총수 일가가 법정에 나...
# 8                   문재인 전 대표의 어제(19일) 발언을 놓고 오늘도 공격이 이어...
# 9                   세월호를 들어올릴 쇠줄이 배의 무게중심에 맞게 위치해 있는가를 ...
# 10                  박근혜 전 대통령은 검찰이 할 예상질문들을 뽑아서 답변을 준비하...
# 11                  그럼 소환조사를 하루 앞두고 긴장감이 높아지고 있는 박 전 대통...
# 12                  검찰은 박 전 대통령이 대기업들에 대한 압박과 지원 요청을 거의...
# 13                  경제가 어렵다곤 하지만 세수가 많이 걷히는 정부는 물론, 기업들...
# 14                  이번에는 이제 내일(21일)입니다. 박근혜 전 대통령 검찰 소환...
# 15                  들으신 대로 자유한국당은 오늘(20일) 후보를 다시 4명으로 줄...
# 16                  검찰은 지난 주말 사이 대기업들 조사를 서둘러 진행했습니다. 내...
# 17                  박근혜 전 대통령의 소환 조사가 하루 앞으로 다가왔습니다. 검찰...
# 18                  앞서도 보셨듯이 박 전 대통령의 뇌물 혐의를 보면 거의 언제나 ...
# 19                  이렇게 정부가 내놓은 새로운 대책은 보를 그대로 유지하는 것을 ...
# 20                  세월호 인양을 누구보다 간절한 마음으로 기다리는 건, 시신 수습...
# 21                  날씨 알아보겠습니다. 오늘(20일) 춘분인데 이제 봄기운도 완연...
# 22                정식개장을 앞둔 롯데월드타워에서 승강기가 고장나는 사고가 있었습니다...
# 23                  롯데그룹 총수 일가의 비리 혐의 관련 재판이 오늘(20일)부터 ...
# 24                  렉스 틸러슨 미국 국무장관이 한중일 3개국 순방을 마치고 미국으...
# 25                  브라질의 대형 육가공 업체들이 썩은 닭고기, 쇠고기를 팔다가 적...
# 26                  정부가 4대강 수질 문제를 해결하기 위한 새로운 대책을 내놨습니...
# 27                  박 전대통령의 이른바 비선의료진들이 국회에서의 위증을 인정하며 ...
# 28                  넉 달 동안 누적인원 1600만 명. 광장의 촛불은 평화로웠고 ...
# 29             중진공 '채용 외압' 의혹 최경환 의원 불구속 기소  (JTBC 뉴스운영...
#                                ...
# 40604        충남과 전북에서 내일 아침까지 1cm 미만의 눈이 내리겠지만, 나머지 대부분...
# 40605        보신 것처럼 새누리당이 인적청산을 놓고 또다시 정면충돌 양상으로 치닫고 있습...
# 40606        2016년의 마지막 날인 오늘(31일) 광화문광장에서 제10차 촛불집회가 열...
# 40607        박영수 특별검사팀은 오늘(31일) 오전부터 김희범 전 문체부 차관을 불러 조...
# 40608        황교안 대통령 권한대행이 어제(30일) 차관급 인사로 문화체육관광부 1차관에...
# 40609        국회 국정조사 특별위원회는 다음달 9일 최순실 국정농단 사건의 진상규명을 위...
# 40610        10년 임기를 끝내고 돌아오는 반기문 유엔 사무총장이 개헌이 필요하다는 입장...
# 40611        경기도 포천의 고양이 사체에서 발견된 AI 바이러스가 현재 유행하고 있는 H...
# 40612        베이징을 비롯한 중국 수도권을 스모그가 또 다시 강타했습니다. 중국 환경당국...
# 40613        2016년의 마지막 날인 오늘(31일)은 전국이 포근한 날씨를 보이겠습니다....
# 40614        특검, '정유라 특혜 의혹' 류철균 이대 교수 긴급 체포'소설가 이인화' 류...
# 40615        전국 4년제 대학 196곳이 31일부터 2017학년도 정시모집 원서 접수를 ...
# 40616        10차 촛불집회가 열리고 있는 서울 광화문광장 등 현장을 연결해서 차례로 지...
# 40617        다음은 오늘(31일)밤 2016년을 마감하면서 상징적인 장소죠. 제야의 종이...
# 40618        서울 뿐 아니라 전국의 곳곳에서 촛불집회가 진행되고 있죠. 조금 전 확인한 ...
# 40619        2016년도 이제 4시간여 밖에 남지 않았습니다. 앞서 보신 것처럼 올 한해...
# 40620        서울 광화문 광장 한복판에서 종이배 접기가 한창입니다. 박근혜 대통령 퇴진을...
# 40621        오늘(31일) 부산에서 열린 촛불집회에 참석한 시민들은 현재 동구 일본영사관...
# 40622        이번엔 광주로 가보겠습니다. 광주 금남로에선 10차, 촛불 시국대회가 열리고...
# 40623        지금 전남 진도의 동거차도에서도 찬 바닷바람을 맞으며 새해맞이를 준비하는 사...
# 40624        지금부터는 박영수 특별검사팀의 수사 속보를 전해드리겠습니다. 오늘(31일) ...
# 40625        이런 가운데 최순실 전횡을 밝히겠다면서 출범했던 문화체육관광부 내 태스크포스...
# 40626        문제는 여기서 끝나지 않습니다. 황교안 대통령 권한대행이 어제(30일) 임명...
# 40627        박영수 특별검사팀이 오늘(31일) 새벽 이화여대 류철균 교수를 긴급 체포했습...
# 40628        인명진 새누리당 비대위원장이 어제(30일), 친박계 핵심인사들을 향해 다음달...
# 40629        경기도 포천에서 AI에 걸려 폐사한 고양이에 대한 정밀검사 결과가 나왔습니다...
# 40630        여기서 다시 광화문 광장 집회 현장으로 가보겠습니다. 지금 '송박영신' 콘서...
# 40631        내일(1일)은 전국이 대체로 포근하겠지만, 중국 북동부 지역을 강타한 스모그...
# 40632        지금 이 시각 광화문 광장 외에도 서울 종로 보신각에도 많은 시민들이 모여들...
# 40633        내년은 대선이 치러지는 해죠. 조기 대선이 유력한 상황에서 어느 때보다 승부...
# Name: article, Length: 40634, dtype: object

# %%
counts=df.groupby('section').size()
sorted_counts=counts.sort_values(ascending=False)

# %%
sorted_counts
# Out:
# section
# 사회      12334
# JTBC    10575
# 정치      10316
# 국제       3415
# 경제       1917
# 문화        731
# 스포츠       679
# 날씨        665
# 기타          1
#             1
# dtype: int64

# %%
df.to_pickle('jtbc_all.pkl')

# %%
df.memory_usage(deep=True)
# Out:
# Index         2360328
# article    1181572465
# author       28497751
# date         19767747
# section      29771250
# title        59625664
# sec_idx       2360328
# dtype: int64
